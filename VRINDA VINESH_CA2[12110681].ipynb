# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
# Load the data
data = np.loadtxt('wheat_seedscsv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [39], in <cell line: 2>()
#       1 # Load the data
# ----> 2 data = np.loadtxt('wheat_seedscsv')
#
# File ~\anaconda3\lib\site-packages\numpy\lib\npyio.py:1067, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1065     fname = os_fspath(fname)
#    1066 if _is_string_like(fname):
# -> 1067     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1068     fencoding = getattr(fh, 'encoding', 'latin1')
#    1069     fh = iter(fh)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# ...

# %%
# Load the data
data = np.loadtxt('wheat-seed.csv', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 # Load the data
# ----> 2 data = np.loadtxt('wheat-seed.csv', delimiter=',')
#
# File ~\anaconda3\lib\site-packages\numpy\lib\npyio.py:1067, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1065     fname = os_fspath(fname)
#    1066 if _is_string_like(fname):
# -> 1067     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1068     fencoding = getattr(fh, 'encoding', 'latin1')
#    1069     fh = iter(fh)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# ...

# %%
import numpy as np

# Load the data
data = np.loadtxt('wheat_seeds.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 4>()
#       1 import numpy as np
#       3 # Load the data
# ----> 4 data = np.loadtxt('wheat_seeds.csv')
#
# File ~\anaconda3\lib\site-packages\numpy\lib\npyio.py:1148, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1143 # read data in chunks and fill it into an array via resize
#    1144 # over-allocating and shrinking the array later may be faster but is
#    1145 # probably not relevant compared to the cost of actually reading and
#    1146 # converting the data
#    1147 X = None
# -> 1148 for x in read_data(_loadtxt_chunksize):
#    1149     if X is None:
#    1150         X = np.array(x, dtype)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\npyio.py:999, in loadtxt.<locals>.read_data(chunk_size)
# ...

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
#Read the given CSV file, and view some sample records
wheats = pd.read_csv('wheat_seeds.csv')
wheats.head(10)
# Out:
#     area  perimeter  compactness  length_kernel  width_kernel  \
# 0  15.26      14.84       0.8710          5.763         3.312
# 1  14.88      14.57       0.8811          5.554         3.333
# 2  14.29      14.09       0.9050          5.291         3.337
# 3  13.84      13.94       0.8955          5.324         3.379
# 4  16.14      14.99       0.9034          5.658         3.562
# 5  14.38      14.21       0.8951          5.386         3.312
# 6  14.69      14.49       0.8799          5.563         3.259
# 7  14.11      14.10       0.8911          5.420         3.302
# 8  16.63      15.46       0.8747          6.053         3.465
# 9  16.44      15.25       0.8880          5.884         3.505
#
#    length_kernel_groove  wheat_type
# 0                 5.220           1
# 1                 4.956           1
# 2                 4.825           1
# 3                 4.805           1
# 4                 5.175           1
# 5                 4.956           1
# ...

# %%
# Info our dataset
wheats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   area                  210 non-null    float64
#  1   perimeter             210 non-null    float64
#  2   compactness           210 non-null    float64
#  3   length_kernel         210 non-null    float64
#  4   width_kernel          210 non-null    float64
#  5   length_kernel_groove  210 non-null    float64
#  6   wheat_type            210 non-null    int64
# dtypes: float64(6), int64(1)
# memory usage: 11.6 KB

# %% [markdown]
# The wheat_type column is the target variable, which is of integer type and has no missing values. The other columns are the features used to predict the target variable, which are all of float type and have no missing values.

# %%
wheats['wheat_type'].value_counts()
# Out:
# 1    114
# 2     96
# Name: wheat_type, dtype: int64

# %%
sns.countplot(wheats['wheat_type'],label="Count")
plt.show()

# %% [markdown]
# If the count of Type 1 wheat is higher than Type 2 wheat, it suggests that the dataset may be imbalanced, i.e., it contains more samples of Type 1 wheat than Type 2 wheat. This could potentially affect the performance of machine learning models trained on this dataset, as the models may be biased towards predicting the majority class.

# %%
sns.pairplot(wheats.drop('wheat_type' ,axis=1))

# %% [markdown]
# # building the model

# %%
# Creating X and y
X = wheats[['area','perimeter','compactness','length_kernel','width_kernel','length_kernel_groove']]
y = fruits['wheat_type']

# %%
# Splitting the varaibles as training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.8, random_state = 999)

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
classifier_svc = SVC()
classifier_svc.fit(X_train,y_train)
classifier_svc
# Out:
# SVC()

# %%
y_pred = classifier_svc.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 2>()
#       1 y_pred = classifier_svc.predict(X_test)
# ----> 2 print(accuracy_score(y_test,y_pred))
#
# NameError: name 'accuracy_score' is not defined

# %%
# Accuracy

y_pred=classifier_lr.predict(X_test)

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 3>()
#       1 # Accuracy
# ----> 3 y_pred=classifier_lr.predict(X_test)
#       5 from sklearn.metrics import accuracy_score
#       6 print(accuracy_score(y_test,y_pred))
#
# NameError: name 'classifier_lr' is not defined

# %%
from sklearn.linear_model import LogisticRegression
classifier_lr = LogisticRegression() 
classifier_lr.fit(X_train,y_train)
classifier_lr
# Out:
# LogisticRegression()

# %%
# Accuracy

y_pred=classifier_lr.predict(X_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8273809523809523

# %%
y_pred = classifier_svc.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8154761904761905

# %% [markdown]
# having 81.55% accuracy is pretty good.

# %%
fig = plt.figure()
sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, cmap='Blues', fmt='g', linewidths=2, linecolor='black', 
            xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 2>()
#       1 fig = plt.figure()
# ----> 2 sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, cmap='Blues', fmt='g', linewidths=2, linecolor='black',
#       3             xticklabels=labels, yticklabels=labels)
#       4 plt.xlabel('Predicted')
#       5 plt.ylabel('Actual')
#
# NameError: name 'confusion_matrix' is not defined

# %%
print("CONFUSION MATRIX")
labels = ['Type1', 'Type2']
fig = plt.figure()
sns.heatmap(confusion_matrix(y_test,y_pred), annot=True,cmap='Blues',fmt='g',linewidths=2, linecolor='black',
           xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# CONFUSION MATRIX
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 4>()
#       2 labels = ['Type1', 'Type2']
#       3 fig = plt.figure()
# ----> 4 sns.heatmap(confusion_matrix(y_test,y_pred), annot=True,cmap='Blues',fmt='g',linewidths=2, linecolor='black',
#       5            xticklabels=labels, yticklabels=labels)
#       6 plt.xlabel('Predicted')
#       7 plt.ylabel('Actual')
#
# NameError: name 'confusion_matrix' is not defined

# %%
from sklearn.metrics import confusion_matrix

# %%
print("CONFUSION MATRIX")
labels = ['Type1', 'Type2']
fig = plt.figure(figsize=(12, 6))
sns.heatmap(confusion_matrix(y_test,y_pred), annot=True,cmap='Reds',fmt='g',linewidths=2, linecolor='black',
           xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# CONFUSION MATRIX

# %% [markdown]
# An accuracy score of 0.827 indicates that the models are able to correctly predict the class labels of approximately 83% of the samples in the test set.The confusion matrix shows that the SVM model is predicting wheat seed type with an accuracy of 92.86%.

# %% [markdown]
# The confusion matrix shows that there are 85 true positives (Type1 samples correctly classified as Type1), 52 true negatives (Type2 samples correctly classified as Type2), 3 false negatives (Type1 samples incorrectly classified as Type2), and 28 false positives (Type2 samples incorrectly classified as Type1).The confusion matrix also shows that the SVM model is now more likely to misclassify type 1 wheat seeds as type 2 wheat seeds than vice versa. This is because the model has learned that there are more type 2 wheat seeds in the test set, and it is therefore more likely to predict type 2 for any given wheat seed.

# %% [markdown]
#  using the confusion_matrix() function from the sklearn.metrics module we can get an output of this function will be a matrix that shows the number of true positive, true negative, false positive, and false negative predictions for each class.

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier_knn= KNeighborsClassifier()
classifier_knn.fit(X_train, y_train)
classifier_knn
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier_knn.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.7976190476190477

# %% [markdown]
# The accuracy_score() function from the sklearn.metrics module is used to knoe the accuracy of the y_pred compared to the true class labels (y_test).

# %% [markdown]
# An accuracy score of 79.76% on the wheat seeds dataset is not bad, but it could be improved. There are a few things you can do to try to improve the accuracy of your model:
# In here the default distance metric for knn used is the euclidean distance but we can use manhattan distance or others for it
# Assigning weights to neighbours based on similarity of datset can improve accuracy too

# %%
print("CONFUSION MATRIX")
labels = ['Type1', 'Type2']
fig = plt.figure(figsize=(10, 6))
sns.heatmap(confusion_matrix(y_test,y_pred), annot=True,cmap='Greens',fmt='g',linewidths=2, linecolor='black',
           xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# CONFUSION MATRIX

# %% [markdown]
# The confusion matrix shows that the SVM model is predicting wheat seed type with an accuracy of 88.64%.
# The confusion matrix also shows that the SVM model is more likely to misclassify type 2 wheat seeds as type 1 wheat seeds than vice versa. This is because there are more type 1 wheat seeds in the test set than type 2 wheat seeds.Overall the confusion matrix is great.
